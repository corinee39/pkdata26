# %%
ba = 'BaNaNa'
ba = ba.lower()
print(ba)
ba = "*".join(ba)
print(ba)
ba = ba.split("*")
print(ba)
# Out:
# banana
# b*a*n*a*n*a
# ['b', 'a', 'n', 'a', 'n', 'a']

# %%
name = ["홍길동", "이순신", "슈퍼맨", "배트맨", "박서방"]
age = [22, 33, 34, 12, 54]

print(dict([[x, y] for x, y in zip(name, age)]))
# Out:
# {'홍길동': 22, '이순신': 33, '슈퍼맨': 34, '배트맨': 12, '박서방': 54}

# %%
students = [("jane",22,"A"),("dave",32,"B"),("sally",17,"B")]

[name, age, grade] = [[x[i] for x in students] for i in range(3)]
# students[1][0]
print(name, age, grade, sep='\n')
# Out:
# ['jane', 'dave', 'sally']
# [22, 32, 17]
# ['A', 'B', 'B']
